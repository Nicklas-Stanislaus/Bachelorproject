# %%
# Importing testfunctions and algorithms
import numpy as np
import matplotlib.pyplot as plt
import time

import TestFunctionsAndBoundaries.TestFunctions as tf

from Algorithms.PSO import PSO
from Algorithms.GA import GA
from Algorithms.SA import SA
from Algorithms.TS import TS

# %%
## Tuning parameters

dim = 5
fn = tf.Sum_squares
bound = tf.Sum_squares_bounds
print(bound)


values = []
random_start = time.time()
for i in range(500000): 
    point = np.random.uniform(bound[0], bound[1], dim)
    values.append(fn(point))    
random_time = round(time.time() - random_start, 4)

print("time: ",  random_time,  " res: ",min(values))
print("-----")

SA_start = time.time()
## L is usually number of dims and a 0.9
res_SA = fn(SA(fn, bound, dim, T = 10, L = 50, a = 0.90, iterations = 100))
SA_time = round(time.time() - SA_start, 4)
print("time: ",  SA_time,  " res: ",res_SA)

TS_start = time.time()
res_TS = fn(TS(fn, bound, dim, m = 10, n_neighbors = 5, h0 = 0.1, iterations = 2000))
TS_time = round(time.time() - TS_start, 4)
print("time: ",  TS_time,  " res: ",res_TS)

GA_start = time.time()
res_GA = fn(GA(fn, bound, dim, n_pop = 10, x_rate = 0.5, mutation_rate = 0.01, iterations = 3000))
GA_time = round(time.time() - GA_start, 4)
print("time: ",  GA_time,  " res: ",res_GA)

PSO_start = time.time()
res_PSO = fn(PSO(fn, bound, dim, n_particles = 20, w = 0.73, c1 = 2.05, c2 = 2.05, v_max = 10, iterations = 250))
PSO_time = round(time.time() - PSO_start, 4)
print("time: " , PSO_time, " res: ", res_PSO)
# Out:
# [-10, 10]
# time:  2.5899  res:  1.415155722440853
# -----
# time:  0.1181  res:  0.546613058163573
# time:  0.5324  res:  0.006144971613822941
# time:  0.2882  res:  0.019622430108173036
# time:  0.054  res:  0.0

# %%
### PARAMETERS 
function_params = [("Sphere", tf.Sphere, tf.Sphere_bounds, tf.Sphere_opt), 
                       ("Elliptic", tf.Elliptic, tf.Elliptic_bounds, tf.Elliptic_opt),
                       ("Rastrigin", tf.Rastrigin, tf.Rastrigin_bounds, tf.Rastrigin_opt),
                       ("Ackley", tf.Ackley, tf.Ackley_bounds, tf.Ackley_opt),
                       ("Schwefel_1_2", tf.Schwefel_1_2, tf.Schwefel_1_2_bounds, tf.Schwefel_1_2_opt),
                       ("Schwefel", tf.Schwefel, tf.Schwefel_bounds, tf.Schwefel_opt),
                       ("Rosenbrock", tf.Rosenbrock, tf.Rosenbrock_bounds, tf.Rosenbrock_opt),
                       ("Griewank", tf.Griewank, tf.Griewank_bounds, tf.Griewank_opt),
                       ("Sum_of_different_powers", tf.Sum_of_different_powers, tf.Sum_of_different_powers_bounds, tf.Sum_of_different_powers_opt),
                       ("Sum_squares", tf.Sum_squares, tf.Sum_squares_bounds, tf.Sum_squares_opt)]

    
algorithm_params = [("Sphere", {"T":100, "L": 50, "a": 0.90, "iterations": 500}, 
                                   {"m" : 5, "n_neighbors" : 5, "h0" : 0.05, "iterations" : 11800}, 
                                   {"n_pop": 10, "x_rate": 0.5, "mutation_rate": 0.01, "iterations" : 12000}, 
                                   {"n_particles": 20, "w" : 0.73, "c1": 2.05, "c2": 2.05, "v_max": 0.1, "iterations": 2200},
                                   {"iterations": 165000}), 
                        
                       ("Elliptic", {"T":100, "L": 50, "a": 0.90, "iterations": 350}, 
                                   {"m" : 10, "n_neighbors" : 5, "h0" : 1, "iterations" : 6700}, 
                                   {"n_pop": 10, "x_rate": 0.5, "mutation_rate": 0.01, "iterations" : 7200}, 
                                   {"n_particles": 20, "w" : 0.73, "c1": 2.05, "c2": 2.05, "v_max": 100, "iterations": 1150},
                                   {"iterations": 87500}),
                        
                       ("Rastrigin", {"T":100, "L": 50, "a": 0.90, "iterations": 200}, 
                                   {"m" : 20, "n_neighbors" : 5, "h0" : 0.05, "iterations" : 3500}, 
                                   {"n_pop": 10, "x_rate": 0.5, "mutation_rate": 0.01, "iterations" : 3650}, 
                                   {"n_particles": 20, "w" : 0.73, "c1": 2.05, "c2": 2.05, "v_max": 0.1, "iterations": 500},
                                   {"iterations": 40000}),
                        
                       ("Ackley", {"T":100, "L": 50, "a": 0.90, "iterations": 210}, 
                                   {"m" : 20, "n_neighbors" : 5, "h0" : 0.05, "iterations" : 3500}, 
                                   {"n_pop": 10, "x_rate": 0.5, "mutation_rate": 0.01, "iterations" : 3700}, 
                                   {"n_particles": 20, "w" : 0.73, "c1": 5, "c2": 5, "v_max": 1, "iterations": 520},
                                   {"iterations": 42000}),
                    
                       ("Schwefel_1_2", {"T":100, "L": 50, "a": 0.90, "iterations": 80}, 
                                   {"m" : 20, "n_neighbors" : 5, "h0" : 1, "iterations" : 1500}, 
                                   {"n_pop": 20, "x_rate": 0.5, "mutation_rate": 0.01, "iterations" : 700}, 
                                   {"n_particles": 20, "w" : 0.73, "c1": 2.05, "c2": 2.05, "v_max": 100, "iterations": 180},
                                   {"iterations": 14000}),
                        
                       ("Schwefel", {"T":100, "L": 50, "a": 0.90, "iterations": 165}, 
                                   {"m" : 20, "n_neighbors" : 5, "h0" : 1, "iterations" : 2900}, 
                                   {"n_pop": 10, "x_rate": 0.5, "mutation_rate": 0.01, "iterations" : 2900}, 
                                   {"n_particles": 20, "w" : 0.73, "c1": 5, "c2": 5, "v_max": 100, "iterations": 380},
                                   {"iterations": 31000}),
                    
                       ("Rosenbrock", {"T":100, "L": 50, "a": 0.90, "iterations": 250}, 
                                   {"m" : 20, "n_neighbors" : 5, "h0" : 0.1, "iterations" : 3800}, 
                                   {"n_pop": 10, "x_rate": 0.5, "mutation_rate": 0.01, "iterations" : 4800}, 
                                   {"n_particles": 20, "w" : 0.73, "c1": 5, "c2": 5, "v_max": 0.1, "iterations": 680},
                                   {"iterations": 31000}),
                    
                       ("Griewank", {"T":100, "L": 50, "a": 0.90, "iterations": 130}, 
                                   {"m" : 20, "n_neighbors" : 5, "h0" : 1, "iterations" : 2150}, 
                                   {"n_pop": 10, "x_rate": 0.5, "mutation_rate": 0.01, "iterations" : 2000}, 
                                   {"n_particles": 20, "w" : 0.73, "c1": 5, "c2": 5, "v_max": 10, "iterations": 280},
                                   {"iterations": 22500}),
                        
                       ("Sum_of_different_powers", {"T":100, "L": 50, "a": 0.90, "iterations": 470}, 
                                   {"m" : 10, "n_neighbors" : 5, "h0" : 0.01, "iterations" : 5000}, 
                                   {"n_pop": 10, "x_rate": 0.5, "mutation_rate": 0.01, "iterations" : 11000}, 
                                   {"n_particles": 20, "w" : 0.73, "c1": 2.05, "c2": 2.05, "v_max": 1, "iterations": 2000},
                                   {"iterations": 150000}),
                    
                       ("Sum_squares",{"T":10, "L": 50, "a": 0.90, "iterations": 440}, 
                                   {"m" : 10, "n_neighbors" : 5, "h0" : 0.1, "iterations" : 8000}, 
                                   {"n_pop": 10, "x_rate": 0.5, "mutation_rate": 0.01, "iterations" : 10000}, 
                                   {"n_particles": 20, "w" : 0.73, "c1": 2.05, "c2": 2.05, "v_max": 10, "iterations": 1800},
                                   {"iterations": 150000})]

# %%
# Generating data 

dims = 5
runs = 50

for fp, ap in zip(function_params, algorithm_params):
    assert(fp[0] == ap[0])
    print(f"{fp[0]}, optimal value: {fp[3]} \n")
    names = ["SA", "TS", "GA", "PSO"]
    
    SA_start = time.time()
    SA(fp[1], fp[2], dims, T = ap[1]["T"], L = ap[1]["L"], a = ap[1]["a"], iterations = ap[1]["iterations"])
    SA_time = round(time.time() - SA_start,4)
    
    TS_start = time.time()
    TS(fp[1], fp[2], dims, m = ap[2]["m"], n_neighbors = ap[2]["n_neighbors"], h0 = ap[2]["h0"], iterations = ap[2]["iterations"])
    TS_time = round(time.time() - TS_start,4)
    
    GA_start = time.time()
    GA(fp[1], fp[2], dims, n_pop = ap[3]["n_pop"], x_rate = ap[3]["x_rate"], mutation_rate = ap[3]["mutation_rate"], iterations = ap[3]["iterations"])
    GA_time = round(time.time() - GA_start,4)
    
    PSO_start = time.time()
    PSO(fp[1], fp[2], dims, n_particles = ap[4]["n_particles"], w = ap[4]["w"], c1 = ap[4]["c1"], c2 = ap[4]["c2"], v_max = ap[4]["v_max"], iterations = ap[4]["iterations"])
    PSO_time = round(time.time() - PSO_start,4)
    
    print(f"SA time: {SA_time}, TS time: {TS_time}, GA time: {GA_time}, PSO time: {PSO_time}")
    
    fastest = np.argmin([SA_time, TS_time, GA_time, PSO_time])
    slowest = np.argmax([SA_time, TS_time, GA_time, PSO_time])
    
    print(f"Fastest: {names[fastest]}, slowest: {names[slowest]} \n")
    
    RNG_values = []
    for i in range(runs): 
        RNG_run = []
        for i in range(ap[5]["iterations"]): 
            point = np.random.uniform(fp[2][0], fp[2][1], dims)
            RNG_run.append(fp[1](point))
        RNG_values.append(min(RNG_run))
    print(f"RNG mean: {np.mean(RNG_values)}, RNG std: {np.std(RNG_values)}, RNG best: {min(RNG_values)}")
    
    TS_values = []
    for i in range(runs): 
        point = TS(fp[1], fp[2], dims, m = ap[2]["m"], n_neighbors = ap[2]["n_neighbors"], h0 = ap[2]["h0"], iterations = ap[2]["iterations"])
        fit_value = fp[1](point)
        TS_values.append(fit_value)
    print(f"TS mean: {np.mean(TS_values)}, TS std: {np.std(TS_values)}, TS best: {min(TS_values)}")
    
    SA_values = []
    for i in range(runs): 
        point = SA(fp[1], fp[2], dims, T = ap[1]["T"], L = ap[1]["L"], a = ap[1]["a"], iterations = ap[1]["iterations"])
        fit_value = fp[1](point)
        SA_values.append(fit_value)
    print(f"SA mean: {np.mean(SA_values)}, SA std: {np.std(SA_values)}, SA best: {min(SA_values)}")
    
    GA_values = []
    for i in range(runs): 
        point = GA(fp[1], fp[2], dims, n_pop = ap[3]["n_pop"], x_rate = ap[3]["x_rate"], mutation_rate = ap[3]["mutation_rate"], iterations = ap[3]["iterations"])
        fit_value = fp[1](point)
        GA_values.append(fit_value)
    print(f"GA mean: {np.mean(GA_values)}, GA std: {np.std(GA_values)}, GA best: {min(GA_values)}")
    
    PSO_values = []
    for i in range(runs): 
        point = PSO(fp[1], fp[2], dims, n_particles = ap[4]["n_particles"], w = ap[4]["w"], c1 = ap[4]["c1"], c2 = ap[4]["c2"], v_max = ap[4]["v_max"], iterations = ap[4]["iterations"])
        fit_value = fp[1](point)
        PSO_values.append(fit_value)
    print(f"PSO mean: {np.mean(PSO_values)}, PSO std: {np.std(PSO_values)}, PSO best: {min(PSO_values)} \n")
    
    means = [np.mean(SA_values), np.mean(TS_values), np.mean(GA_values), np.mean(PSO_values)]
    best_vals =[min(SA_values), min(TS_values), min(GA_values), min(PSO_values)]
    best_mean = np.argmin(means) 
    best_val = np.argmin(best_vals)
    print(f"Best average: {names[best_mean]}, value: {means[best_mean]}")
    print(f"Best val: {names[best_val]}, value: {best_vals[best_val]}")
    
    np.save(f'{fp[0]}_{dims}Dims_{runs}Runs_SA.npy', SA_values)
    np.save(f'{fp[0]}_{dims}Dims_{runs}Runs_TS.npy', TS_values)
    np.save(f'{fp[0]}_{dims}Dims_{runs}Runs_GA.npy', GA_values)
    np.save(f'{fp[0]}_{dims}Dims_{runs}Runs_PSO.npy', PSO_values)
    np.save(f'{fp[0]}_{dims}Dims_{runs}Runs_RNG.npy', RNG_values)
    
    print("-------------------------------------------------------------------------")
# Out:
# Sphere, optimal value: 0
#
# SA time: 2.5448, TS time: 2.4629, GA time: 2.2686, PSO time: 2.6739
# Fastest: GA, slowest: PSO
#
# RNG mean: 0.24245157120895292, RNG std: 0.09744753148966334, RNG best: 0.060638025969851975
# TS mean: 0.00027937116669001985, TS std: 0.00012789484620446198, TS best: 6.961402173551863e-05
# SA mean: 0.027933980643237002, SA std: 0.013471119557941244, SA best: 0.002917870067140636
# GA mean: 7.813559553608028e-06, GA std: 9.57749047087012e-06, GA best: 2.814146052073796e-07
# PSO mean: 9.57221759729667e-10, PSO std: 6.934875459983099e-10, PSO best: 1.0376479275931671e-10
#
# Best average: PSO, value: 9.57221759729667e-10
# Best val: PSO, value: 1.0376479275931671e-10
# -------------------------------------------------------------------------
# Elliptic, optimal value: 0
#
# SA time: 2.3777, TS time: 2.6034, GA time: 2.6189, PSO time: 2.5608
# Fastest: SA, slowest: GA
#
# RNG mean: 1769.40637091591, RNG std: 838.6113754792437, RNG best: 268.1780478782114
# TS mean: 63.364850099139495, TS std: 76.74865867389818, TS best: 8.723774251070585
# SA mean: 389.5535365528356, SA std: 231.46690952793085, SA best: 52.65085034459736
# GA mean: 3.0586692012126133, GA std: 6.694001464492037, GA best: 0.010988500760565727
# PSO mean: 0.0, PSO std: 0.0, PSO best: 0.0
#
# Best average: PSO, value: 0.0
# Best val: PSO, value: 0.0
# -------------------------------------------------------------------------
# Rastrigin, optimal value: 0
#
# SA time: 2.59, TS time: 2.9261, GA time: 2.3897, PSO time: 2.812
# Fastest: GA, slowest: TS
#
# RNG mean: 9.067074280390884, RNG std: 2.0235301303097724, RNG best: 4.066193278090978
# TS mean: 43.06506465551202, TS std: 15.095873535618203, TS best: 16.02010359536807
# SA mean: 4.232432879992202, SA std: 1.2037191169028068, SA best: 1.609880527188139
# GA mean: 0.0029172806052059743, GA std: 0.0025369646998910575, GA best: 8.119883129609207e-05
# PSO mean: 3.9201807674067912, PSO std: 2.1561726052559633, PSO best: 0.994961488109702
#
# Best average: GA, value: 0.0029172806052059743
# Best val: GA, value: 8.119883129609207e-05
# -------------------------------------------------------------------------
# Ackley, optimal value: 0
#
# SA time: 2.693, TS time: 2.5667, GA time: 2.762, PSO time: 2.6418
# Fastest: TS, slowest: GA
#
# RNG mean: 7.236905685182441, RNG std: 1.0649664210663972, RNG best: 3.9255247077163706
# TS mean: 19.46496363436048, TS std: 0.40089655298569987, TS best: 17.93453097543224
# SA mean: 3.6373121236367667, SA std: 0.5098322929994388, SA best: 2.0549813881005012
# GA mean: 0.04675603827792168, GA std: 0.019963712458955736, GA best: 0.015420564599015751
# PSO mean: 0.0086192875198463, PSO std: 0.0039024325240550662, PSO best: 0.0031654407294827713
#
# Best average: PSO, value: 0.0086192875198463
# Best val: PSO, value: 0.0031654407294827713
# -------------------------------------------------------------------------
# Schwefel_1_2, optimal value: 0
#
# SA time: 2.5148, TS time: 2.6319, GA time: 2.5938, PSO time: 2.4347
# Fastest: PSO, slowest: TS
#
# RNG mean: 26.932179323370093, RNG std: 16.21085633345979, RNG best: 1.4691670446159748
# TS mean: 0.06886519725685612, TS std: 0.037030798218238396, TS best: 0.008070452051855468
# SA mean: 3.5909470488442126, SA std: 2.070668306369629, SA best: 0.23230512786999763
# GA mean: 2.7766591571144845, GA std: 1.6805010667199585, GA best: 0.24692243576812917
# PSO mean: 0.0, PSO std: 0.0, PSO best: 0.0
#
# Best average: PSO, value: 0.0
# Best val: PSO, value: 0.0
# -------------------------------------------------------------------------
# Schwefel, optimal value: 0
#
# SA time: 2.3721, TS time: 2.5689, GA time: 2.5418, PSO time: 2.4487
# Fastest: SA, slowest: TS
#
# RNG mean: 279.033748205612, RNG std: 78.95590005839513, RNG best: 66.64387910279606
# TS mean: 837.521501086324, TS std: 391.93905820646006, TS best: -39.45016656237067
# SA mean: 338.85737803356164, SA std: 126.94654618686037, SA best: 35.857026683134336
# GA mean: 0.017928869242523432, GA std: 0.017374290352265835, GA best: 0.00039336403733614134
# PSO mean: 611.9183774953916, PSO std: 195.57662070195235, PSO best: 122.43431486691384
#
# Best average: GA, value: 0.017928869242523432
# Best val: TS, value: -39.45016656237067
# -------------------------------------------------------------------------
# Rosenbrock, optimal value: 0
#
# SA time: 2.6877, TS time: 2.6058, GA time: 2.4147, PSO time: 2.4768
# Fastest: GA, slowest: SA
#
# RNG mean: 39.92998927828654, RNG std: 19.07468253960787, RNG best: 0.7449665560960961
# TS mean: 0.7825741244112379, TS std: 0.3494651800806627, TS best: 0.14354744653886947
# SA mean: 7.592688095029188, SA std: 5.2245134377257445, SA best: 2.382966458587514
# GA mean: 1.8278617109988693, GA std: 1.5566566488551519, GA best: 0.04645769555328635
# PSO mean: 0.8315919794050727, PSO std: 1.4002663015568453, PSO best: 0.00329008640650768
#
# Best average: TS, value: 0.7825741244112379
# Best val: PSO, value: 0.00329008640650768
# -------------------------------------------------------------------------
# Griewank, optimal value: 0
#
# SA time: 2.783, TS time: 2.6875, GA time: 2.7739, PSO time: 2.9151
# Fastest: TS, slowest: PSO
#
# RNG mean: 2.6125317719571903, RNG std: 0.6230168394329014, RNG best: 0.7373679254822223
# TS mean: 0.09865536106877075, TS std: 0.021245710353617088, TS best: 0.050621192724704556
# SA mean: 0.9539066661558021, SA std: 0.20859559909832884, SA best: 0.33340626394627737
# GA mean: 0.06518107515443962, GA std: 0.02942202450253306, GA best: 0.022939004681830966
# PSO mean: 0.09903630452797603, PSO std: 0.0381884552763475, PSO best: 0.04295175519717853
#
# Best average: GA, value: 0.06518107515443962
# Best val: GA, value: 0.022939004681830966
# -------------------------------------------------------------------------
# Sum_of_different_powers, optimal value: 0
#
# SA time: 2.6823, TS time: 2.4974, GA time: 2.7859, PSO time: 2.6007
# Fastest: TS, slowest: GA
#
# RNG mean: 0.00018155999052422482, RNG std: 0.00011613582866639702, RNG best: 4.192908465828108e-05
# TS mean: 4.383118636636352e-08, TS std: 2.4580919857520814e-08, TS best: 9.446850388905639e-09
# SA mean: 5.0076883198073325e-06, SA std: 3.6290986554155946e-06, SA best: 4.587912383135134e-07
# GA mean: 2.8828907319526735e-08, GA std: 5.846070662702574e-08, GA best: 2.6960395698086425e-13
# PSO mean: 0.0, PSO std: 0.0, PSO best: 0.0
#
# Best average: PSO, value: 0.0
# Best val: PSO, value: 0.0
# -------------------------------------------------------------------------
# Sum_squares, optimal value: 0
#
# SA time: 2.9012, TS time: 2.5127, GA time: 2.5848, PSO time: 2.5557
# Fastest: TS, slowest: SA
#
# RNG mean: 2.3165050825535958, RNG std: 0.9087299907634174, RNG best: 0.4469116593976982
# TS mean: 0.00367413358600328, TS std: 0.0013810035997604405, TS best: 0.00039832501994105797
# SA mean: 0.287266480242345, SA std: 0.11472628909411461, SA best: 0.07317286122381826
# GA mean: 6.34740796105814e-05, GA std: 6.490335571990451e-05, GA best: 4.590691481514374e-06
# PSO mean: 0.0, PSO std: 0.0, PSO best: 0.0
#
# Best average: PSO, value: 0.0
# Best val: PSO, value: 0.0
# -------------------------------------------------------------------------

# %%
# Generating figures 

bounds = tf.Griewank_bounds
func = tf.Griewank


fig = plt.figure(figsize = (12,10))
ax = plt.axes(projection='3d')

x = np.arange(-200, 200, 0.5)
y = np.arange(-200, 200, 0.5)
#x = np.arange(-10, 10, 0.1)
#y = np.arange(-10, 10, 0.1)

X, Y = np.meshgrid(x, y)

Z = np.array([[func([x,y]) for x, y in zip(x_list,y_list)] for x_list, y_list in zip(X,Y)])

surf = ax.plot_surface(X, Y, Z, cmap = plt.cm.viridis)

# Set axes label
ax.set_xlabel('x', labelpad=20)
ax.set_ylabel('y', labelpad=20)
ax.set_zlabel('z', labelpad=20)

fig.colorbar(surf, shrink=0.5, aspect=8)

plt.show()

# %%
# Testing visualization data output 
its = 10

data_viz_PSO = PSO(tf.Sphere, tf.Sphere_bounds, 3, iterations = its, visualize = True)
print(data_viz_PSO, "\n")

data_viz_GA = GA(tf.Sphere, tf.Sphere_bounds, 3, iterations = its, visualize = True)
print(data_viz_GA, "\n")

data_viz_TS = TS(tf.Sphere, tf.Sphere_bounds, 3, iterations = its, visualize = True)
print(data_viz_TS, "\n")

data_viz_SA = SA(tf.Sphere, tf.Sphere_bounds, 3, iterations = its,  visualize = True)
print(data_viz_SA, "\n")
# Out:
# [array([-0.16699833,  2.88752658,  0.57409445]), array([0.37329432, 1.8969125 , 1.55225175]), array([-1.45142771,  0.50192532,  0.64339319]), array([ 0.37329432,  0.7302402 , -0.28123809]), array([-0.66926705,  0.42211358, -0.13146062]), array([-0.66926705,  0.42211358, -0.13146062]), array([-0.14206709,  0.11149187, -0.35756773]), array([-0.15244788, -0.02861586, -0.24794522]), array([-0.08708952, -0.25859994, -0.01466628]), array([-0.08708952, -0.25859994, -0.01466628])]
#
# [array([ 1.05681944, -1.10075874,  1.15719212]), array([ 0.21828051, -1.10075874,  1.15719212]), array([ 0.73984651, -0.91400527,  0.31228208]), array([ 0.73984651, -0.91400527,  0.31228208]), array([ 0.73984651, -0.91400527,  0.31228208]), array([ 0.6910123 , -0.91400527,  0.31228208]), array([0.85959786, 0.18846153, 0.31228208]), array([0.85959786, 0.18846153, 0.31228208]), array([ 0.6910123 , -0.25748094,  0.31228208]), array([ 0.6910123 , -0.25748094,  0.31228208])]
#
# [array([-0.89186364, -0.0687398 ,  1.62884374]), array([-0.89186364, -0.0687398 ,  1.62884374]), array([-0.46303739, -0.32390803,  0.88767143]), array([-0.55044946,  0.15821883,  0.73571352]), array([-0.55044946,  0.15821883,  0.73571352]), array([-0.55044946,  0.15821883,  0.73571352]), array([-0.55044946,  0.15821883,  0.73571352]), array([-0.55044946,  0.15821883,  0.73571352]), array([-0.55044946,  0.15821883,  0.73571352]), array([-0.55044946,  0.15821883,  0.73571352])]
#
# [array([1.09316323, 0.05283848, 1.76272447]), array([1.09316323, 0.05283848, 1.76272447]), array([1.09316323, 0.05283848, 1.76272447]), array([-1.02686236,  1.13607477, -0.44524592]), array([-0.13082775, -0.06290545, -0.29965753]), array([-0.13082775, -0.06290545, -0.29965753]), array([-0.13082775, -0.06290545, -0.29965753]), array([-0.13082775, -0.06290545, -0.29965753]), array([-0.13082775, -0.06290545, -0.29965753]), array([-0.13082775, -0.06290545, -0.29965753])]

# %%
#generating visualization data 

dims = 50
runs = 50
its = 1000

counter = 1
for fp, ap in zip(function_params, algorithm_params):
    assert(fp[0] == ap[0])
    print(f"{fp[0]}, function {counter}, started")
    
    TS_values = np.zeros(its)
    for i in range(runs): 
        points = TS(fp[1], fp[2], dims, m = ap[2]["m"], n_neighbors = ap[2]["n_neighbors"], h0 = ap[2]["h0"], iterations = its, visualize = True)
        fit_vals = np.array([fp[1](point) / runs for point in points])
        TS_values += fit_vals
    
    SA_values = np.zeros(its)
    for i in range(runs): 
        points = SA(fp[1], fp[2], dims, T = ap[1]["T"], L = ap[1]["L"], a = ap[1]["a"], iterations = its, visualize = True)
        fit_vals = np.array([fp[1](point) / runs for point in points])
        SA_values += fit_vals

    
    GA_values = np.zeros(its)
    for i in range(runs): 
        points = GA(fp[1], fp[2], dims, n_pop = ap[3]["n_pop"], x_rate = ap[3]["x_rate"], mutation_rate = ap[3]["mutation_rate"], iterations = its, visualize = True)
        fit_vals = np.array([fp[1](point) / runs for point in points])
        GA_values += fit_vals

    
    PSO_values = np.zeros(its)
    for i in range(runs): 
        points = PSO(fp[1], fp[2], dims, n_particles = ap[4]["n_particles"], w = ap[4]["w"], c1 = ap[4]["c1"], c2 = ap[4]["c2"], v_max = ap[4]["v_max"], iterations = its, visualize = True)
        fit_vals = np.array([fp[1](point) / runs for point in points])
        PSO_values += fit_vals
    
    np.save(f'{fp[0]}_{dims}Dims_{its}its_{runs}Runs_SA_viz.npy', SA_values)
    np.save(f'{fp[0]}_{dims}Dims_{its}its_{runs}Runs_TS_viz.npy', TS_values)
    np.save(f'{fp[0]}_{dims}Dims_{its}its_{runs}Runs_GA_viz.npy', GA_values)
    np.save(f'{fp[0]}_{dims}Dims_{its}its_{runs}Runs_PSO_viz.npy', PSO_values)
    print(f"{fp[0]}, function {counter}, ended")
    counter += 1
# Out:
# Sphere, function 1, started
# Sphere, function 1, ended
# Elliptic, function 2, started
# Elliptic, function 2, ended
# Rastrigin, function 3, started
# Rastrigin, function 3, ended
# Ackley, function 4, started
# Ackley, function 4, ended
# Schwefel_1_2, function 5, started
# Schwefel_1_2, function 5, ended
# Schwefel, function 6, started
# Schwefel, function 6, ended
# Rosenbrock, function 7, started
# Rosenbrock, function 7, ended
# Griewank, function 8, started
# Griewank, function 8, ended
# Sum_of_different_powers, function 9, started
# Sum_of_different_powers, function 9, ended
# Sum_squares, function 10, started
# Sum_squares, function 10, ended

# %%
# Creating iteration figures 

from matplotlib.lines import Line2D

dims = 50
runs = 50
its = 1000

x_axis = 5
y_axis = 2

# For plots
fig, axs = plt.subplots(x_axis, y_axis, figsize=(7, 14))
plot_positions = [(x,y) for x in range(x_axis)for y in range(y_axis)]
iterations = list(range(its))

function_names = ["Sphere", "Sum_squares", "Sum_of_different_powers", "Elliptic", "Schwefel_1_2", "Schwefel", "Rastrigin", "Ackley", "Rosenbrock", "Griewank"]
function_id = ["F1", "F2", "F3","F4","F5", "F6","F7", "F8","F9", "F10"]
for name, plot_pos,function_id  in zip(function_names, plot_positions, function_id):
    
    pp1 = plot_pos[0]
    pp2 = plot_pos[1]
    
    #Loading data
    SA = np.load(f'{name}_{dims}Dims_{its}its_{runs}Runs_SA_viz.npy')
    TS = np.load(f'{name}_{dims}Dims_{its}its_{runs}Runs_TS_viz.npy')
    GA = np.load(f'{name}_{dims}Dims_{its}its_{runs}Runs_GA_viz.npy')
    PSO = np.load(f'{name}_{dims}Dims_{its}its_{runs}Runs_PSO_viz.npy')
     
    axs[pp1, pp2].plot(iterations[:800], PSO[:800], color = "purple")
    axs[pp1, pp2].plot(iterations[:800], TS[:800], color = "black")
    axs[pp1, pp2].plot(iterations[:800], GA[:800], color = "green")
    axs[pp1, pp2].plot(iterations[:800], SA[:800], color = "blue")
    axs[pp1, pp2].axhline(y=0.0, color='r', linestyle='dotted')
    axs[pp1, pp2].set_title(function_id)
    axs[pp1, pp2].grid(linewidth=0.5)

    
# Set labels
#for ax in axs.flat:
#    ax.set(xlabel='Iterations', ylabel='Fitness value')

# Hide x labels and tick labels for top plots and y ticks for right plots
#for ax in axs.flat:
#    ax.label_outer()


legend_elements = [Line2D([0], [0], color='purple', lw=4, label='Line'),
                   Line2D([0], [0], color='black', lw=4, label='Line'),
                  Line2D([0], [0], color='green', lw=4, label='Line'),
                  Line2D([0], [0], color='blue', lw=4, label='Line')]

# Create the figure

fig.legend(bbox_to_anchor=(1.15, 0.5), handles=legend_elements, labels = ["PSO", "TS", "GA", "SA"], loc='center right', borderaxespad=0)

fig.tight_layout()

fig.text(0.5, -0.01, 'Iterations', ha='center', fontsize = "x-large")
fig.text(-0.01, 0.5, 'Objective function value', va='center', rotation='vertical', fontsize = "x-large")

plt.savefig('test.jpeg', bbox_inches='tight')

# %%
# Creating latex tables 
counter = 1
dims = 50
runs = 250
for name in ["Sphere", "Sum_squares", "Sum_of_different_powers", "Elliptic", "Schwefel_1_2", "Schwefel", "Rastrigin", "Ackley", "Rosenbrock", "Griewank"]:  
    RNG = np.load(f'{name}_{dims}Dims_{runs}Runs_RNG.npy')
    TS = np.load(f'{name}_{dims}Dims_{runs}Runs_TS.npy')
    SA = np.load(f'{name}_{dims}Dims_{runs}Runs_SA.npy')
    GA = np.load(f'{name}_{dims}Dims_{runs}Runs_GA.npy')
    PSO = np.load(f'{name}_{dims}Dims_{runs}Runs_PSO.npy')
    
    print(f"$F{counter}_{{{dims}D}}$ & ", "{:.3e}".format(np.mean(RNG))," & ","{:.3e}".format(np.mean(TS))," & ", \
          "{:.3e}".format(np.mean(SA))," & ", "{:.3e}".format(np.mean(GA))," & ", "{:.3e}".format(np.mean(PSO)), " \\\\", sep='')
    
    print("& (", "{:.3e}".format(np.std(RNG)),") & (","{:.3e}".format(np.std(TS)),") & (", "{:.3e}".format(np.std(SA)), \
          ") & (", "{:.3e}".format(np.std(GA)),") & (", "{:.3e}".format(np.std(PSO)), ") \\\\", sep='')
    
    print(f"& ", "{:.3e}".format(np.min(RNG))," & ","{:.3e}".format(np.min(TS))," & ", \
          "{:.3e}".format(np.min(SA))," & ", "{:.3e}".format(np.min(GA))," & ", "{:.3e}".format(np.min(PSO)), " \\\\", sep='')
    print("\hline")
    counter +=1
# Out:
# $F1_{50D}$ & 2.102e+02 & 1.059e-02 & 4.456e+01 & 4.605e-03 & 3.400e-03 \\
# & (1.230e+01) & (8.656e-04) & (4.050e+00) & (1.435e-03) & (7.927e-04) \\
# $F1_{50D}$ & 1.510e+02 & 7.509e-03 & 3.168e+01 & 1.758e-03 & 1.567e-03 \\
# \hline
# $F2_{50D}$ & 1.807e+04 & 1.138e+00 & 4.126e+03 & 6.827e-01 & 0.000e+00 \\
# & (1.186e+03) & (1.076e-01) & (4.469e+02) & (2.596e-01) & (0.000e+00) \\
# $F2_{50D}$ & 1.357e+04 & 7.696e-01 & 2.922e+03 & 2.254e-01 & 0.000e+00 \\
# \hline
# $F3_{50D}$ & 9.545e-02 & 4.706e-07 & 4.525e-03 & 2.260e-06 & 0.000e+00 \\
# & (3.006e-02) & (1.940e-07) & (4.169e-03) & (4.489e-06) & (0.000e+00) \\
# $F3_{50D}$ & 2.135e-02 & 8.712e-08 & 3.428e-04 & 9.381e-11 & 0.000e+00 \\
# \hline
# $F4_{50D}$ & 9.150e+08 & 1.564e+06 & 1.970e+08 & 1.643e+05 & 4.000e+01 \\
# & (1.431e+08) & (3.726e+05) & (3.375e+07) & (1.312e+05) & (6.312e+02) \\
# $F4_{50D}$ & 5.221e+08 & 6.892e+05 & 1.155e+08 & 1.897e+04 & 0.000e+00 \\
# \hline
# $F5_{50D}$ & 1.273e+05 & 8.514e+03 & 7.321e+04 & 4.947e+04 & 9.836e+03 \\
# & (1.568e+04) & (2.894e+03) & (9.753e+03) & (9.713e+03) & (1.670e+04) \\
# $F5_{50D}$ & 8.750e+04 & 3.083e+03 & 4.999e+04 & 2.668e+04 & 0.000e+00 \\
# \hline
# $F6_{50D}$ & 1.533e+04 & 8.174e+03 & 1.558e+04 & 1.011e+02 & 1.266e+04 \\
# & (3.928e+02) & (1.092e+03) & (4.813e+02) & (3.070e+01) & (1.306e+03) \\
# $F6_{50D}$ & 1.368e+04 & 5.332e+03 & 1.445e+04 & 4.435e+01 & 9.537e+03 \\
# \hline
# $F7_{50D}$ & 6.315e+02 & 4.407e+02 & 5.899e+02 & 8.464e+00 & 5.462e+01 \\
# & (2.026e+01) & (5.054e+01) & (3.965e+01) & (1.669e+00) & (1.243e+01) \\
# $F7_{50D}$ & 5.296e+02 & 3.019e+02 & 4.971e+02 & 3.406e+00 & 3.020e+01 \\
# \hline
# $F8_{50D}$ & 2.030e+01 & 1.954e+01 & 1.682e+01 & 1.933e+00 & 3.165e+00 \\
# & (9.022e-02) & (1.149e-01) & (5.684e-01) & (2.555e-01) & (4.506e-01) \\
# $F8_{50D}$ & 1.997e+01 & 1.911e+01 & 1.533e+01 & 1.201e+00 & 2.090e+00 \\
# \hline
# $F9_{50D}$ & 1.461e+06 & 1.008e+02 & 7.936e+04 & 1.978e+02 & 1.796e+02 \\
# & (1.906e+05) & (5.537e+01) & (1.827e+04) & (4.644e+01) & (7.419e+01) \\
# $F9_{50D}$ & 7.991e+05 & 4.431e+01 & 4.062e+04 & 5.847e+01 & 1.650e+01 \\
# \hline
# $F10_{50D}$ & 7.878e+02 & 6.704e+02 & 2.049e+02 & 1.656e+00 & 1.168e+00 \\
# & (4.781e+01) & (1.355e+02) & (2.256e+01) & (1.926e-01) & (3.279e-02) \\
# $F10_{50D}$ & 6.304e+02 & 3.709e+02 & 1.506e+02 & 1.306e+00 & 1.090e+00 \\
# \hline

# %%
runs = 50
counter = 1
for name in ["Sphere", "Sum_squares", "Sum_of_different_powers", "Elliptic", "Schwefel_1_2", "Schwefel", "Rastrigin", "Ackley", "Rosenbrock", "Griewank"]:  
    for dims in [5,10,25,100]:
        RNG = np.load(f'{name}_{dims}Dims_{runs}Runs_RNG.npy')
        TS = np.load(f'{name}_{dims}Dims_{runs}Runs_TS.npy')
        SA = np.load(f'{name}_{dims}Dims_{runs}Runs_SA.npy')
        GA = np.load(f'{name}_{dims}Dims_{runs}Runs_GA.npy')
        PSO = np.load(f'{name}_{dims}Dims_{runs}Runs_PSO.npy')

        print(f"$F{counter}_{{{dims}D}}$ & ", "{:.3e}".format(np.mean(RNG))," & ","{:.3e}".format(np.mean(TS))," & ", \
              "{:.3e}".format(np.mean(SA))," & ", "{:.3e}".format(np.mean(GA))," & ", "{:.3e}".format(np.mean(PSO)), " \\\\", sep='')

        print("& (", "{:.3e}".format(np.std(RNG)),") & (","{:.3e}".format(np.std(TS)),") & (", "{:.3e}".format(np.std(SA)), \
              ") & (", "{:.3e}".format(np.std(GA)),") & (", "{:.3e}".format(np.std(PSO)), ") \\\\", sep='')

        print(f"& ", "{:.3e}".format(np.min(RNG))," & ","{:.3e}".format(np.min(TS))," & ", \
              "{:.3e}".format(np.min(SA))," & ", "{:.3e}".format(np.min(GA))," & ", "{:.3e}".format(np.min(PSO)), " \\\\", sep='')
        print("\hline")
    counter +=1
# Out:
# $F1_{5D}$ & 2.425e-01 & 2.794e-04 & 2.793e-02 & 7.814e-06 & 9.572e-10 \\
# & (9.745e-02) & (1.279e-04) & (1.347e-02) & (9.577e-06) & (6.935e-10) \\
# & 6.064e-02 & 6.961e-05 & 2.918e-03 & 2.814e-07 & 1.038e-10 \\
# \hline
# $F1_{10D}$ & 5.786e+00 & 4.828e-04 & 5.960e-01 & 6.402e-05 & 1.535e-07 \\
# & (1.461e+00) & (1.209e-04) & (1.423e-01) & (4.804e-05) & (9.979e-08) \\
# & 1.913e+00 & 2.299e-04 & 7.048e-02 & 6.109e-06 & 2.307e-08 \\
# \hline
# $F1_{25D}$ & 6.604e+01 & 3.355e-03 & 8.487e+00 & 6.245e-04 & 7.633e-05 \\
# & (5.979e+00) & (4.527e-04) & (1.081e+00) & (2.811e-04) & (2.947e-05) \\
# & 4.992e+01 & 2.417e-03 & 6.295e+00 & 1.669e-04 & 3.168e-05 \\
# \hline
# $F1_{100D}$ & 5.532e+02 & 3.018e-02 & 2.281e+02 & 1.719e-01 & 1.094e-01 \\
# & (1.791e+01) & (2.462e-03) & (1.523e+01) & (3.351e-02) & (1.672e-02) \\
# & 4.983e+02 & 2.443e-02 & 1.956e+02 & 9.260e-02 & 7.657e-02 \\
# \hline
# $F2_{5D}$ & 2.317e+00 & 3.674e-03 & 2.873e-01 & 6.347e-05 & 0.000e+00 \\
# & (9.087e-01) & (1.381e-03) & (1.147e-01) & (6.490e-05) & (0.000e+00) \\
# & 4.469e-01 & 3.983e-04 & 7.317e-02 & 4.591e-06 & 0.000e+00 \\
# \hline
# $F2_{10D}$ & 1.131e+02 & 1.317e-02 & 1.067e+01 & 1.708e-03 & 0.000e+00 \\
# & (2.114e+01) & (3.090e-03) & (2.600e+00) & (1.264e-03) & (0.000e+00) \\
# & 6.272e+01 & 3.229e-03 & 4.359e+00 & 1.084e-04 & 0.000e+00 \\
# \hline
# $F2_{25D}$ & 2.680e+03 & 1.752e-01 & 3.845e+02 & 4.249e-02 & 0.000e+00 \\
# & (3.105e+02) & (2.456e-02) & (7.183e+01) & (2.040e-02) & (0.000e+00) \\
# & 1.994e+03 & 1.128e-01 & 1.915e+02 & 1.409e-02 & 0.000e+00 \\
# \hline
# $F2_{100D}$ & 9.926e+04 & 2.189e+03 & 3.845e+04 & 5.467e+01 & 0.000e+00 \\
# & (4.466e+03) & (1.167e+03) & (2.324e+03) & (1.443e+01) & (0.000e+00) \\
# & 8.502e+04 & 6.067e+02 & 3.067e+04 & 3.035e+01 & 0.000e+00 \\
# \hline
# $F3_{5D}$ & 1.816e-04 & 4.383e-08 & 5.008e-06 & 2.883e-08 & 0.000e+00 \\
# & (1.161e-04) & (2.458e-08) & (3.629e-06) & (5.846e-08) & (0.000e+00) \\
# & 4.193e-05 & 9.447e-09 & 4.588e-07 & 2.696e-13 & 0.000e+00 \\
# \hline
# $F3_{10D}$ & 3.140e-03 & 2.287e-08 & 2.764e-05 & 4.846e-07 & 0.000e+00 \\
# & (1.638e-03) & (1.608e-08) & (1.258e-05) & (1.532e-06) & (0.000e+00) \\
# & 1.586e-04 & 9.339e-10 & 5.848e-06 & 5.045e-11 & 0.000e+00 \\
# \hline
# $F3_{25D}$ & 3.165e-02 & 2.122e-07 & 2.902e-04 & 1.279e-06 & 0.000e+00 \\
# & (1.082e-02) & (1.091e-07) & (3.044e-04) & (3.198e-06) & (0.000e+00) \\
# & 8.844e-03 & 4.184e-08 & 3.784e-05 & 5.556e-10 & 0.000e+00 \\
# \hline
# $F3_{100D}$ & 2.336e-01 & 9.600e-07 & 9.287e-01 & 8.652e-06 & 0.000e+00 \\
# & (6.492e-02) & (2.937e-07) & (6.058e-01) & (1.567e-05) & (0.000e+00) \\
# & 7.029e-02 & 4.798e-07 & 6.976e-02 & 1.405e-09 & 0.000e+00 \\
# \hline
# $F4_{5D}$ & 1.769e+03 & 6.336e+01 & 3.896e+02 & 3.059e+00 & 0.000e+00 \\
# & (8.386e+02) & (7.675e+01) & (2.315e+02) & (6.694e+00) & (0.000e+00) \\
# & 2.682e+02 & 8.724e+00 & 5.265e+01 & 1.099e-02 & 0.000e+00 \\
# \hline
# $F4_{10D}$ & 7.420e+05 & 1.008e+04 & 1.377e+05 & 2.280e+02 & 0.000e+00 \\
# & (2.611e+05) & (6.426e+03) & (5.355e+04) & (2.637e+02) & (0.000e+00) \\
# & 1.173e+05 & 2.553e+03 & 4.702e+04 & 3.141e+00 & 0.000e+00 \\
# \hline
# $F4_{25D}$ & 9.069e+07 & 2.374e+05 & 1.807e+07 & 8.707e+03 & 1.151e+02 \\
# & (2.054e+07) & (8.289e+04) & (4.976e+06) & (9.532e+03) & (8.056e+02) \\
# & 3.666e+07 & 1.233e+05 & 5.992e+06 & 6.215e+02 & 0.000e+00 \\
# \hline
# $F4_{100D}$ & 5.043e+09 & 1.233e+07 & 1.408e+09 & 2.890e+06 & 0.000e+00 \\
# & (4.144e+08) & (2.040e+06) & (1.744e+08) & (1.413e+06) & (0.000e+00) \\
# & 3.836e+09 & 7.999e+06 & 1.014e+09 & 1.022e+06 & 0.000e+00 \\
# \hline
# $F5_{5D}$ & 2.693e+01 & 6.887e-02 & 3.591e+00 & 2.777e+00 & 0.000e+00 \\
# & (1.621e+01) & (3.703e-02) & (2.071e+00) & (1.681e+00) & (0.000e+00) \\
# & 1.469e+00 & 8.070e-03 & 2.323e-01 & 2.469e-01 & 0.000e+00 \\
# \hline
# $F5_{10D}$ & 2.009e+03 & 2.197e+00 & 2.114e+02 & 2.120e+02 & 0.000e+00 \\
# & (4.397e+02) & (6.233e-01) & (6.032e+01) & (1.573e+02) & (0.000e+00) \\
# & 9.913e+02 & 7.951e-01 & 8.767e+01 & 1.525e+01 & 0.000e+00 \\
# \hline
# $F5_{25D}$ & 2.829e+04 & 5.390e+01 & 9.486e+03 & 7.467e+03 & 0.000e+00 \\
# & (3.449e+03) & (1.073e+01) & (2.157e+03) & (2.321e+03) & (0.000e+00) \\
# & 2.216e+04 & 3.458e+01 & 5.322e+03 & 2.923e+03 & 0.000e+00 \\
# \hline
# $F5_{100D}$ & 5.382e+05 & 1.313e+06 & 3.800e+05 & 2.389e+05 & 1.756e+05 \\
# & (6.575e+04) & (1.306e+06) & (5.987e+04) & (3.983e+04) & (1.130e+05) \\
# & 3.489e+05 & 3.232e+05 & 2.752e+05 & 1.591e+05 & 6.066e+02 \\
# \hline
# $F6_{5D}$ & 2.790e+02 & 8.375e+02 & 3.389e+02 & 1.793e-02 & 6.119e+02 \\
# & (7.896e+01) & (3.919e+02) & (1.269e+02) & (1.737e-02) & (1.956e+02) \\
# & 6.664e+01 & -3.945e+01 & 3.586e+01 & 3.934e-04 & 1.224e+02 \\
# \hline
# $F6_{10D}$ & 1.570e+03 & 1.652e+03 & 1.532e+03 & 4.862e-01 & 1.725e+03 \\
# & (1.280e+02) & (5.844e+02) & (1.955e+02) & (3.682e-01) & (3.324e+02) \\
# & 1.240e+03 & 4.344e+02 & 9.659e+02 & 9.731e-02 & 9.089e+02 \\
# \hline
# $F6_{25D}$ & 6.356e+03 & 4.092e+03 & 6.564e+03 & 7.785e+00 & 5.478e+03 \\
# & (2.558e+02) & (9.273e+02) & (3.203e+02) & (3.153e+00) & (7.131e+02) \\
# & 5.658e+03 & 2.390e+03 & 5.848e+03 & 1.686e+00 & 3.951e+03 \\
# \hline
# $F6_{100D}$ & 3.419e+04 & 2.195e+04 & 3.470e+04 & 2.613e+03 & 3.040e+04 \\
# & (5.849e+02) & (1.565e+03) & (5.849e+02) & (3.749e+02) & (1.999e+03) \\
# & 3.227e+04 & 1.948e+04 & 3.313e+04 & 1.745e+03 & 2.596e+04 \\
# \hline
# $F7_{5D}$ & 9.067e+00 & 4.307e+01 & 4.232e+00 & 2.917e-03 & 3.920e+00 \\
# & (2.024e+00) & (1.510e+01) & (1.204e+00) & (2.537e-03) & (2.156e+00) \\
# & 4.066e+00 & 1.602e+01 & 1.610e+00 & 8.120e-05 & 9.950e-01 \\
# \hline
# $F7_{10D}$ & 5.564e+01 & 8.288e+01 & 3.745e+01 & 7.603e-02 & 1.061e+01 \\
# & (5.229e+00) & (2.400e+01) & (5.582e+00) & (5.438e-02) & (3.918e+00) \\
# & 4.328e+01 & 2.208e+01 & 2.384e+01 & 1.053e-02 & 2.986e+00 \\
# \hline
# $F7_{25D}$ & 2.515e+02 & 2.179e+02 & 2.056e+02 & 6.829e-01 & 2.743e+01 \\
# & (1.482e+01) & (3.980e+01) & (2.245e+01) & (2.991e-01) & (8.270e+00) \\
# & 2.048e+02 & 1.310e+02 & 1.543e+02 & 2.184e-01 & 1.110e+01 \\
# \hline
# $F7_{100D}$ & 1.448e+03 & 8.785e+02 & 1.422e+03 & 8.865e+01 & 2.999e+02 \\
# & (2.641e+01) & (7.172e+01) & (6.496e+01) & (7.963e+00) & (3.263e+01) \\
# & 1.343e+03 & 7.438e+02 & 1.312e+03 & 7.209e+01 & 2.204e+02 \\
# \hline
# $F8_{5D}$ & 7.237e+00 & 1.946e+01 & 3.637e+00 & 4.676e-02 & 8.619e-03 \\
# & (1.065e+00) & (4.009e-01) & (5.098e-01) & (1.996e-02) & (3.902e-03) \\
# & 3.926e+00 & 1.793e+01 & 2.055e+00 & 1.542e-02 & 3.165e-03 \\
# \hline
# $F8_{10D}$ & 1.477e+01 & 1.944e+01 & 7.393e+00 & 2.290e-01 & 8.459e-02 \\
# & (1.026e+00) & (3.533e-01) & (7.115e-01) & (1.006e-01) & (2.923e-02) \\
# & 1.153e+01 & 1.776e+01 & 5.146e+00 & 7.371e-02 & 2.433e-02 \\
# \hline
# $F8_{25D}$ & 1.938e+01 & 1.950e+01 & 1.268e+01 & 5.629e-01 & 1.371e+00 \\
# & (2.610e-01) & (1.809e-01) & (5.307e-01) & (1.575e-01) & (5.343e-01) \\
# & 1.822e+01 & 1.904e+01 & 1.065e+01 & 3.053e-01 & 6.815e-01 \\
# \hline
# $F8_{100D}$ & 2.071e+01 & 1.955e+01 & 2.055e+01 & 5.041e+00 & 6.456e+00 \\
# & (5.440e-02) & (7.973e-02) & (2.948e-01) & (2.659e-01) & (6.289e-01) \\
# & 2.053e+01 & 1.934e+01 & 1.964e+01 & 4.258e+00 & 5.367e+00 \\
# \hline
# $F9_{5D}$ & 3.993e+01 & 7.826e-01 & 7.593e+00 & 1.828e+00 & 8.316e-01 \\
# & (1.907e+01) & (3.495e-01) & (5.225e+00) & (1.557e+00) & (1.400e+00) \\
# & 7.450e-01 & 1.435e-01 & 2.383e+00 & 4.646e-02 & 3.290e-03 \\
# \hline
# $F9_{10D}$ & 3.903e+03 & 3.932e+00 & 1.729e+02 & 3.932e+00 & 8.097e+00 \\
# & (1.302e+03) & (1.177e+01) & (7.800e+01) & (2.653e+00) & (2.360e+01) \\
# & 1.231e+03 & 7.346e-01 & 3.440e+01 & 1.323e-01 & 7.417e-03 \\
# \hline
# $F9_{25D}$ & 2.038e+05 & 3.279e+01 & 5.501e+03 & 6.026e+01 & 5.792e+01 \\
# & (3.364e+04) & (3.026e+01) & (1.510e+03) & (3.666e+01) & (4.655e+01) \\
# & 1.231e+05 & 9.027e+00 & 1.560e+03 & 5.190e+00 & 1.941e+00 \\
# \hline
# $F9_{100D}$ & 5.423e+06 & 7.234e+05 & 7.741e+05 & 1.087e+03 & 1.620e+03 \\
# & (4.407e+05) & (2.071e+05) & (1.373e+05) & (2.400e+02) & (4.070e+02) \\
# & 3.863e+06 & 3.325e+05 & 5.169e+05 & 5.780e+02 & 1.135e+03 \\
# \hline
# $F10_{5D}$ & 2.613e+00 & 9.866e-02 & 9.539e-01 & 6.518e-02 & 9.904e-02 \\
# & (6.230e-01) & (2.125e-02) & (2.086e-01) & (2.942e-02) & (3.819e-02) \\
# & 7.374e-01 & 5.062e-02 & 3.334e-01 & 2.294e-02 & 4.295e-02 \\
# \hline
# $F10_{10D}$ & 3.120e+01 & 2.519e-01 & 4.048e+00 & 4.509e-01 & 3.477e-01 \\
# & (7.746e+00) & (5.059e-02) & (7.075e-01) & (1.774e-01) & (1.202e-01) \\
# & 9.461e+00 & 1.327e-01 & 2.017e+00 & 2.016e-01 & 9.083e-02 \\
# \hline
# $F10_{25D}$ & 2.664e+02 & 8.346e+00 & 3.891e+01 & 1.042e+00 & 9.206e-01 \\
# & (2.236e+01) & (8.280e+00) & (4.918e+00) & (3.413e-02) & (7.121e-02) \\
# & 2.071e+02 & 5.473e-01 & 2.922e+01 & 8.638e-01 & 5.675e-01 \\
# \hline
# $F10_{100D}$ & 2.006e+03 & 2.461e+03 & 1.078e+03 & 2.522e+01 & 1.946e+01 \\
# & (7.605e+01) & (2.677e+02) & (7.144e+01) & (3.938e+00) & (5.148e+00) \\
# & 1.768e+03 & 1.867e+03 & 9.128e+02 & 1.469e+01 & 1.166e+01 \\
# \hline
